# %%
import numpy as np
from matplotlib import pyplot as plt

from task_2 import hello

hello(print_log=True)
# Out:
# 1
# (7, array([1.09297779, 3.6538843 ]))
# (3, array([0.68998115, 4.18339118]))
# 3
# (10, array([1.36429476, 4.0436509 ]))
# (9, array([0.92945441, 4.26481141]))
# 5
# (13, array([1.19450215, 3.61727392]))
# (9, array([0.70522829, 4.42351594]))
# 7
# (10, array([1.51468743, 3.512719  ]))
# (14, array([1.72871162, 3.47331218]))
# 9
# (12, array([0.84008746, 3.85079637]))
# (14, array([0.79050855, 4.26373932]))
# 11
# (13, array([0.94094851, 3.82593991]))
# (18, array([1.62574327, 3.98099765]))
# 13
# (17, array([0.53393665, 3.95970626]))
# (7, array([1.285599  , 4.14933635]))
# 15
# (18, array([1.48512124, 4.07014844]))
# (9, array([1.03289561, 4.05033787]))
# 17
# (8, array([1.18416791, 4.04831808]))
# (15, array([1.48076799, 4.05914793]))
# 19
# (16, array([0.56919522, 4.44042221]))
# (10, array([0.94983437, 3.92423519]))
# 21
# (6, array([1.14660823, 3.70519082]))
# (18, array([1.47287249, 3.53254459]))
# 23
# (16, array([0.57012039, 4.44181097]))
# ...
